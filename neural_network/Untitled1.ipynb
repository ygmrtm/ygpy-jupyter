# %%
try:
    import import_ipynb    
except ModuleNotFoundError:
    print("Error loading Modules: ",ModuleNotFoundError)
    # %pip install import_ipynb
else:  
    from datetime import date
    import pandas as pd  
    import create_pivot_tables as pivots
# Out:
# importing Jupyter notebook from create_pivot_tables.ipynb
# importing Jupyter notebook from download_from_yahoofinance.ipynb
# Success, no error!
# DJIA
# [*********************100%***********************]  1 of 1 completed
# DOW
# [*********************100%***********************]  1 of 1 completed
# LB
# [*********************100%***********************]  1 of 1 completed
# EXPE
# [*********************100%***********************]  1 of 1 completed
# PXD
# [*********************100%***********************]  1 of 1 completed
# MCHP
# [*********************100%***********************]  1 of 1 completed
# CRM
# [*********************100%***********************]  1 of 1 completed
# NRG
# [*********************100%***********************]  1 of 1 completed
# HFC
# [*********************100%***********************]  1 of 1 completed
# NOW
# [*********************100%***********************]  1 of 1 completed
# SPY
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
ticker_list = pivots.ticker_list
today = pivots.today

# %%
for tik in ticker_list:
    file_name =  str(tik+'_pivot.csv')
    print('===========> '+ file_name)
    df1= pd.read_csv('../data/'+file_name)
# Out:
# ===========> DJIA_pivot.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d994f95b314b> in <module>
#       2     file_name =  str(tik+'_pivot.csv')
#       3     print('===========> '+ file_name)
# ----> 4     df1= pd.read_csv('../data/'+file_name)
#
# ...
